# %%
import gym
from gym import wrappers
import random
import math
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
EPISODES = 200  # number of episodes
EPS_START = 0.9  # e-greedy threshold start value
EPS_END = 0.05  # e-greedy threshold end value
EPS_DECAY = 200  # e-greedy threshold decay
GAMMA = 0.8  # Q-learning discount factor
LR = 0.001  # NN optimizer learning rate
HIDDEN_LAYER = 256  # NN hidden layer size
BATCH_SIZE = 64  # Q-learning batch size

# if gpu is to be used
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor

# %%
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []

    def push(self, transition):
        self.memory.append(transition)
        if len(self.memory) > self.capacity:
            del self.memory[0]

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)


class Network(nn.Module):
    def __init__(self):
        nn.Module.__init__(self)
        self.l1 = nn.Linear(4, HIDDEN_LAYER)
        self.l2 = nn.Linear(HIDDEN_LAYER, 2)

    def forward(self, x):
        x = F.relu(self.l1(x))
        x = self.l2(x)
        return x

# %%
env = gym.make('CartPole-v0')
env = wrappers.Monitor(env, '.', force=True)

model = Network()
if use_cuda:
    model.cuda()
memory = ReplayMemory(10000)
optimizer = optim.Adam(model.parameters(), LR)
steps_done = 0
episode_durations = []

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    
        
    if sample > eps_threshold:
        return model(Variable(state).type(FloatTensor)).data.max(1)[1].view(1, 1)
    else:
        return LongTensor([[random.randrange(2)]])

# %%
def run_episode(e, environment):
    state = environment.reset()
    steps = 0
    while True:
        environment.render()
        action = select_action(FloatTensor([state]))
        next_state, reward, done, _ = environment.step(action[0, 0].item() )

        # negative reward when attempt ends
        if done:
            reward = -1

        memory.push((FloatTensor([state]),
                     action,  # action is already a tensor
                     FloatTensor([next_state]),
                     FloatTensor([reward])))

        learn()

        state = next_state
        steps += 1

        if done:
            print("{2} Episode {0} finished after {1} steps"
                  .format(e, steps, '\033[92m' if steps >= 195 else '\033[99m'))
            episode_durations.append(steps)
            plot_durations()
            break

# %%
def learn():
    if len(memory) < BATCH_SIZE:
        return

    # random transition batch is taken from experience replay memory
    transitions = memory.sample(BATCH_SIZE)
    batch_state, batch_action, batch_next_state, batch_reward = zip(*transitions)

    batch_state = Variable(torch.cat(batch_state))
    batch_action = Variable(torch.cat(batch_action))
    batch_reward = Variable(torch.cat(batch_reward))
    batch_next_state = Variable(torch.cat(batch_next_state))

    # current Q values are estimated by NN for all actions
    current_q_values = model(batch_state).gather(1, batch_action)
    # expected Q values are estimated from actions which gives maximum Q value
    max_next_q_values = model(batch_next_state).detach().max(1)[0]
    expected_q_values = batch_reward + (GAMMA * max_next_q_values)
    

    # loss is measured from error between current and newly expected Q values
    loss = F.smooth_l1_loss(current_q_values, expected_q_values.view(-1,1))

    # backpropagation of loss to NN
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.FloatTensor(episode_durations)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
for e in range(EPISODES):
    run_episode(e, env)

print('Complete')
env.render(close=True)
env.close()
plt.ioff()
plt.show()
# Out:
#  Episode 0 finished after 33 steps
# ERROR: VideoRecorder encoder exited with status 1
#  Episode 1 finished after 18 steps
# ERROR: VideoRecorder encoder exited with status 1
#  Episode 2 finished after 18 steps
#  Episode 3 finished after 14 steps
#  Episode 4 finished after 15 steps
#  Episode 5 finished after 10 steps
#  Episode 6 finished after 11 steps
#  Episode 7 finished after 12 steps
#  Episode 8 finished after 13 steps
# ERROR: VideoRecorder encoder exited with status 1
#  Episode 9 finished after 12 steps
#  Episode 10 finished after 11 steps
#  Episode 11 finished after 11 steps
#  Episode 12 finished after 11 steps
#  Episode 13 finished after 12 steps
#  Episode 14 finished after 14 steps
#  Episode 15 finished after 10 steps
#  Episode 16 finished after 8 steps
#  Episode 17 finished after 11 steps
#  Episode 18 finished after 15 steps
#  Episode 19 finished after 18 steps
#  Episode 20 finished after 14 steps
#  Episode 21 finished after 16 steps
#  Episode 22 finished after 22 steps
#  Episode 23 finished after 14 steps
#  Episode 24 finished after 20 steps
#  Episode 25 finished after 13 steps
#  Episode 26 finished after 27 steps
#  Episode 27 finished after 35 steps
# ERROR: VideoRecorder encoder exited with status 1
#  Episode 28 finished after 25 steps
#  Episode 29 finished after 31 steps
#  Episode 30 finished after 88 steps
#  Episode 31 finished after 108 steps
#  Episode 32 finished after 134 steps
#  Episode 33 finished after 124 steps
#  Episode 34 finished after 121 steps
#  Episode 35 finished after 89 steps
#  Episode 36 finished after 79 steps
#  Episode 37 finished after 134 steps
#  Episode 38 finished after 104 steps
#  Episode 39 finished after 109 steps
#  Episode 40 finished after 99 steps
#  Episode 41 finished after 139 steps
#  Episode 42 finished after 114 steps
#  Episode 43 finished after 167 steps
#  Episode 44 finished after 172 steps
#  Episode 45 finished after 131 steps
#  Episode 46 finished after 117 steps
#  Episode 47 finished after 111 steps
#  Episode 48 finished after 132 steps
#  Episode 49 finished after 200 steps
#  Episode 50 finished after 146 steps
#  Episode 51 finished after 161 steps
#  Episode 52 finished after 200 steps
#  Episode 53 finished after 200 steps
#  Episode 54 finished after 174 steps
#  Episode 55 finished after 200 steps
#  Episode 56 finished after 164 steps
#  Episode 57 finished after 200 steps
#  Episode 58 finished after 199 steps
#  Episode 59 finished after 200 steps
#  Episode 60 finished after 200 steps
#  Episode 61 finished after 188 steps
#  Episode 62 finished after 153 steps
#  Episode 63 finished after 200 steps
#  Episode 64 finished after 200 steps
# ERROR: VideoRecorder encoder exited with status 1
#  Episode 65 finished after 151 steps
#  Episode 66 finished after 200 steps
#  Episode 67 finished after 154 steps
#  Episode 68 finished after 168 steps
#  Episode 69 finished after 175 steps
#  Episode 70 finished after 185 steps
#  Episode 71 finished after 140 steps
#  Episode 72 finished after 186 steps
#  Episode 73 finished after 93 steps
#  Episode 74 finished after 200 steps
#  Episode 75 finished after 200 steps
#  Episode 76 finished after 200 steps
#  Episode 77 finished after 200 steps
#  Episode 78 finished after 200 steps
#  Episode 79 finished after 161 steps
#  Episode 80 finished after 200 steps
#  Episode 81 finished after 196 steps
#  Episode 82 finished after 188 steps
#  Episode 83 finished after 149 steps
#  Episode 84 finished after 176 steps
#  Episode 85 finished after 200 steps
#  Episode 86 finished after 189 steps
#  Episode 87 finished after 200 steps
#  Episode 88 finished after 152 steps
#  Episode 89 finished after 173 steps
#  Episode 90 finished after 180 steps
#  Episode 91 finished after 188 steps
#  Episode 92 finished after 183 steps
#  Episode 93 finished after 180 steps
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-a49633a253e6>", line 2, in <module>
#     run_episode(e, env)
#   File "<ipython-input-6-eb261b918653>", line 5, in run_episode
#     environment.render()
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/gym/core.py", line 240, in render
#     return self.env.render(mode, **kwargs)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/gym/core.py", line 240, in render
#     return self.env.render(mode, **kwargs)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py", line 213, in render
#     return self.viewer.render(return_rgb_array=mode == 'rgb_array')
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py", line 127, in render
#     self.window.flip()
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/pyglet/window/cocoa/__init__.py", line 296, in flip
#     self.context.flip()
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/pyglet/gl/cocoa.py", line 335, in flip
#     self._nscontext.flushBuffer()
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py", line 805, in __call__
#     return self.method(self.objc_id, *args)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py", line 775, in __call__
#     result = f(objc_id, self.selector, *args)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/kandemir/opt/anaconda3/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-9-a49633a253e6> in <module>
#       1 for e in range(EPISODES):
# ----> 2     run_episode(e, env)
#       3
#
# <ipython-input-6-eb261b918653> in run_episode(e, environment)
#       4     while True:
# ----> 5         environment.render()
#       6         action = select_action(FloatTensor([state]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     212
# --> 213         return self.viewer.render(return_rgb_array=mode == 'rgb_array')
#     214
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#     126             arr = arr[::-1,:,0:3]
# --> 127         self.window.flip()
#     128         self.onetime_geoms = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyglet/window/cocoa/__init__.py in flip(self)
#     295         if self.context:
# --> 296             self.context.flip()
#     297
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyglet/gl/cocoa.py in flip(self)
#     334     def flip(self):
# --> 335         self._nscontext.flushBuffer()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py in __call__(self, *args)
#     804         """Call the method with the given arguments."""
# --> 805         return self.method(self.objc_id, *args)
#     806
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py in __call__(self, objc_id, *args)
#     774         try:
# --> 775             result = f(objc_id, self.selector, *args)
#     776             # Convert result to python type if it is a instance or class pointer.
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
